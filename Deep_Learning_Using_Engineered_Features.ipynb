# %% [markdown]
# ### Imports

# %%
# %pip install seaborn sklearn keras_tuner lightgbm plotly &> /dev/null
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# To store data
# Logging
import logging
import warnings

import matplotlib.pyplot as plt

# To do linear algebra
import numpy as np

# To get new datatypes and functions
from cycler import cycler
from matplotlib.cm import get_cmap

# To create plots
from matplotlib.colors import rgb2hex
from numpy import pi
from scipy.optimize import curve_fit

import pandas as pd
import plotly.graph_objs as go

# To create nicer plots
import seaborn as sns
from keras.layers import Dense, Dropout

# To build models
from keras.models import Sequential
from keras_tuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from kerastuner.tuners import RandomSearch

# To gbm light
from lightgbm import LGBMClassifier

# To create interactive plots
from plotly.offline import init_notebook_mode, iplot

# To process data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow import keras
from tensorflow.keras import layers

# To investigate distributions
# from scipy.stats import norm, probplot, skew
# from sklearn.decomposition import PCA
# from sklearn.manifold import TSNE
# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

logging.getLogger("tensorflow").setLevel(logging.ERROR)
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
# Out:
# 2023-05-30 19:28:05.366887: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-30 19:28:05.663750: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:05.663771: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-30 19:28:06.986192: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:06.986457: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:06.986471: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /tmp/ipykernel_204759/2084868377.py:30: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.engine.hyperparameters import HyperParameters
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Uncompressing data

# %%
# !./unzip.sh test.csv.zip train.csv.zip
# Out:
# Archive:  test.csv.zip
# checkdir:  cannot create extraction directory: test.csv
#            File exists
# File test.csv.zip unzipped successfully to test.csv
# Archive:  train.csv.zip
# checkdir:  cannot create extraction directory: train.csv
#            File exists
# File train.csv.zip unzipped successfully to train.csv

# %%
# Load datasets
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# Combine boths dataframes
train_data["Data"] = "Train"
test_data["Data"] = "Test"
both_data = pd.concat([train_data, test_data], axis=0).reset_index(drop=True)
both_data["subject"] = "#" + both_data["subject"].astype(str)

# Create label
label = both_data.pop("Activity")

print("Shape Train:\t{}".format(train_data.shape))
print("Shape Test:\t{}\n".format(test_data.shape))

train_data.head()
# Out:
# Shape Train:	(7352, 564)
# Shape Test:	(2947, 564)
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  angle(tBodyAccMean,gravity)  \
# 0         -0.923527         -0.934724  ...                    -0.112754
# 1         -0.957686         -0.943068  ...                     0.053477
# 2         -0.977469         -0.938692  ...                    -0.118559
# 3         -0.989302         -0.938692  ...                    -0.036788
# 4         -0.990441         -0.942469  ...                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity   Data
# 0              0.179941             -0.058627        1  STANDING  Train
# 1              0.180289             -0.054317        1  STANDING  Train
# 2              0.180637             -0.049118        1  STANDING  Train
# 3              0.181935             -0.047663        1  STANDING  Train
# 4              0.185151             -0.043892        1  STANDING  Train
#
# [5 rows x 564 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
train_data.shape
# Out:
# (7352, 564)

# %%
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  angle(tBodyAccMean,gravity)  \
# 0         -0.923527         -0.934724  ...                    -0.112754
# 1         -0.957686         -0.943068  ...                     0.053477
# 2         -0.977469         -0.938692  ...                    -0.118559
# 3         -0.989302         -0.938692  ...                    -0.036788
# 4         -0.990441         -0.942469  ...                     0.123320
#
#    angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                              0.030400                         -0.464761
# 1                             -0.007435                         -0.732626
# 2                              0.177899                          0.100699
# 3                             -0.012892                          0.640011
# 4                              0.122542                          0.693578
#
#    angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                             -0.018446             -0.841247
# 1                              0.703511             -0.844788
# 2                              0.808529             -0.848933
# 3                             -0.485366             -0.848649
# 4                             -0.615971             -0.847865
#
#    angle(Y,gravityMean)  angle(Z,gravityMean)  subject  Activity   Data
# 0              0.179941             -0.058627        1  STANDING  Train
# 1              0.180289             -0.054317        1  STANDING  Train
# 2              0.180637             -0.049118        1  STANDING  Train
# 3              0.181935             -0.047663        1  STANDING  Train
# 4              0.185151             -0.043892        1  STANDING  Train
#
# [5 rows x 564 columns]

# %%
train_data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      7352.000000                      7352.000000
# mean                         -0.307009                        -0.625294
# std                           0.321011                         0.307584
# min                          -0.995357                        -0.999765
# 25%                          -0.542602                        -0.845573
# 50%                          -0.343685                        -0.711692
# 75%                          -0.126979                        -0.503878
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  7352.000000                           7352.000000
# mean                      0.008684                              0.002186
# std                       0.336787                              0.448306
# min                      -0.976580                             -1.000000
# 25%                      -0.121527                             -0.289549
# 50%                       0.009509                              0.008943
# 75%                       0.150865                              0.292861
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       7352.000000                           7352.000000
# mean                           0.008726                             -0.005981
# std                            0.608303                              0.477975
# min                           -1.000000                             -1.000000
# 25%                           -0.482273                             -0.376341
# 50%                            0.008735                             -0.000368
# 75%                            0.506187                              0.359368
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           7352.000000           7352.000000           7352.000000
# mean              -0.489547              0.058593             -0.056515
# std                0.511807              0.297480              0.279122
# min               -1.000000             -1.000000             -1.000000
# 25%               -0.812065             -0.017885             -0.143414
# 50%               -0.709417              0.182071              0.003181
# 75%               -0.509079              0.248353              0.107659
# max                1.000000              0.478157              1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %% [markdown]
# ### Checking categorical imbalance

# %%
import plotly.express as px

# dummy change
fig = px.pie(train_data, names="Activity", width=700)
fig.update_layout(
    title={
        "text": "Activities distribution in the data",
        "y": 0.95,
        "x": 0.45,
        "xanchor": "center",
        "yanchor": "top",
    }
)
fig.show()
# Out:
# <div>                            <div id="f4b0f606-0413-490b-a348-e6a2d3b1b37e" class="plotly-graph-div" style="height:525px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4b0f606-0413-490b-a348-e6a2d3b1b37e")) {                    Plotly.newPlot(                        "f4b0f606-0413-490b-a348-e6a2d3b1b37e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Activity=%{label}<extra></extra>","labels":["STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_DOWNSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","WALKING_UPSTAIRS","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","STANDING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","SITTING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","LAYING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALKING","WALK ...

# %%
# Plotting data
label_counts = label.value_counts()

# Get colors
n = label_counts.shape[0]
colormap = get_cmap("viridis")
colors = [rgb2hex(colormap(col)) for col in np.arange(0, 1.01, 1 / (n - 1))]

# Create plot
data = go.Bar(x=label_counts.index, y=label_counts, marker=dict(color=colors))

layout = go.Layout(
    title="Smartphone Activity Label Distribution",
    xaxis=dict(title="Activity"),
    yaxis=dict(title="Count"),
)

fig = go.Figure(data=[data], layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="ee1cf004-cc4d-45c2-943b-2d7443abf9fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee1cf004-cc4d-45c2-943b-2d7443abf9fd")) {                    Plotly.newPlot(                        "ee1cf004-cc4d-45c2-943b-2d7443abf9fd",                        [{"marker":{"color":["#440154","#414487","#2a788e","#22a884","#7ad151","#fde725"]},"x":["LAYING","STANDING","SITTING","WALKING","WALKING_UPSTAIRS","WALKING_DOWNSTAIRS"],"y":[1944,1906,1777,1722,1544,1406],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"c ...
#
# var gd = document.getElementById('ee1cf004-cc4d-45c2-943b-2d7443ab

# %% [markdown]
# ## Prepare Train And Test Data

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
x_train, y_train = train_data.iloc[:, :-2], train_data.iloc[:, -1:]
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_train.shape, y_train.shape
# Out:
# ((7352, 561), (7352, 1))

# %%
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_test.shape, y_test.shape
# Out:
# ((2947, 561), (2947, 1))

# %% [markdown]
# ### One-hot Encoding

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
x_test.shape, y_test.shape, x_train.shape, y_train.shape
# Out:
# ((2947, 561), (2947,), (7352, 561), (7352,))

# %% [markdown]
# ### Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## Base Model

# %%
model = Sequential()
model.add(
    Dense(
        units=64,
        kernel_initializer="normal",
        activation="sigmoid",
        input_dim=x_train.shape[1],
    )
)
model.add(Dropout(0.2))
model.add(Dense(units=6, kernel_initializer="normal", activation="softmax"))
model.compile(
    optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
history = model.fit(
    x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test)
)
model.summary()
# Out:
# 2023-05-30 19:28:18.198549: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-30 19:28:18.198890: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:18.199077: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:18.199130: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:18.199543: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:19.420771: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-05-30 19:28:19.422579: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-05-30 19:28:19.428591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 115/115 [==============================] - 1s 3ms/step - loss: 1.3173 - accuracy: 0.4655 - val_loss: 1.0536 - val_accuracy: 0.5959
# Epoch 2/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.8921 - accuracy: 0.7103 - val_loss: 0.7477 - val_accuracy: 0.8263
# Epoch 3/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.6242 - accuracy: 0.8165 - val_loss: 0.5426 - val_accuracy: 0.8707
# Epoch 4/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.8596 - val_loss: 0.4354 - val_accuracy: 0.8527
# Epoch 5/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3762 - accuracy: 0.8853 - val_loss: 0.3605 - val_accuracy: 0.8985
# Epoch 6/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.3190 - accuracy: 0.8984 - val_loss: 0.3205 - val_accuracy: 0.8887
# Epoch 7/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2735 - accuracy: 0.9113 - val_loss: 0.2891 - val_accuracy: 0.8972
# Epoch 8/10
# 115/115 [==============================] - 0s 2ms/step - loss: 0.2402 - accuracy: 0.9204 - val_loss: 0.2493 - val_accuracy: 0.9240
# Epoch 9/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.2202 - accuracy: 0.9256 - val_loss: 0.2303 - val_accuracy: 0.9223
# Epoch 10/10
# 115/115 [==============================] - 0s 1ms/step - loss: 0.1982 - accuracy: 0.9306 - val_loss: 0.2105 - val_accuracy: 0.9253
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                35968
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 36,358
# Trainable params: 36,358
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Tuning the model

# %%
import tensorflow as tf

def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int("num_layers", 2, 25)):
        model.add(
            layers.Dense(
                units=hp.Int("units" + str(i), min_value=32, max_value=512, step=32),
                kernel_initializer=hp.Choice("initializer", ["uniform", "normal"]),
                activation=hp.Choice("activation", ["relu", "sigmoid", "tanh"]),
            )
        )
    model.add(
        layers.Dense(
            6,
            kernel_initializer=hp.Choice("initializer", ["uniform", "normal"]),
            activation="softmax",
        )
    )
    model.add(Dropout(0.2))
    
    model.compile(
        optimizer=tf.keras.optimizers.legacy.Adam(),  # changed from "adam"
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model



tuner = RandomSearch(
    build_model,
    objective="val_accuracy",
    max_trials=5,
    executions_per_trial=3,
    directory="project",
    project_name="Human_activity_recognition",
)

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 27
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units16 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units17 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units18 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units19 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units20 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units21 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units22 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units23 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
tuner.search(x_train, y_train, epochs=10, validation_data=(x_test, y_test))

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/Human_activity_recognition
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fd33b27a680>
# Trial summary
# Hyperparameters:
# num_layers: 10
# units0: 160
# initializer: normal
# activation: relu
# units1: 352
# units2: 384
# units3: 160
# units4: 512
# units5: 224
# units6: 352
# units7: 416
# units8: 128
# units9: 128
# units10: 64
# units11: 192
# units12: 160
# Score: 0.6795611381530762
# Trial summary
# Hyperparameters:
# num_layers: 24
# units0: 128
# initializer: normal
# activation: relu
# units1: 448
# units2: 128
# units3: 416
# units4: 480
# units5: 160
# units6: 32
# units7: 384
# units8: 448
# units9: 224
# units10: 96
# units11: 480
# units12: 384
# units13: 32
# units14: 32
# units15: 32
# units16: 32
# units17: 32
# units18: 32
# units19: 32
# units20: 32
# units21: 32
# units22: 32
# units23: 32
# Score: 0.5578554471333822
# Trial summary
# Hyperparameters:
# num_layers: 6
# units0: 320
# initializer: uniform
# activation: tanh
# units1: 352
# units2: 32
# units3: 32
# units4: 32
# units5: 32
# Score: 0.3504128356774648
# Trial summary
# Hyperparameters:
# num_layers: 13
# units0: 192
# initializer: uniform
# activation: tanh
# units1: 384
# units2: 96
# units3: 512
# units4: 224
# units5: 128
# units6: 96
# units7: 448
# units8: 32
# units9: 480
# units10: 32
# units11: 32
# units12: 32
# Score: 0.30347245434919995
# Trial summary
# Hyperparameters:
# num_layers: 10
# units0: 384
# initializer: normal
# activation: tanh
# units1: 256
# units2: 512
# units3: 288
# units4: 320
# units5: 288
# units6: 32
# units7: 32
# units8: 32
# units9: 32
# Score: 0.238321453332901

# %%
model = tuner.get_best_models(num_models=1)[0]
history = model.fit(x_train, y_train, epochs=51, validation_data=(x_test, y_test))
# Out:
# Epoch 1/51
# 2023-05-30 19:34:02.499895: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 16497888 exceeds 10% of free system memory.
# 230/230 [==============================] - 3s 10ms/step - loss: 2.0661 - accuracy: 0.6755 - val_loss: 0.5347 - val_accuracy: 0.7693
# Epoch 2/51
# 230/230 [==============================] - 2s 8ms/step - loss: 1.8884 - accuracy: 0.6866 - val_loss: 1.6862 - val_accuracy: 0.7119
# Epoch 3/51
# 230/230 [==============================] - 2s 9ms/step - loss: 1.9968 - accuracy: 0.6866 - val_loss: 1.6591 - val_accuracy: 0.7598
# Epoch 4/51
# 230/230 [==============================] - 2s 8ms/step - loss: 1.8328 - accuracy: 0.6963 - val_loss: 0.6290 - val_accuracy: 0.8059
# Epoch 5/51
# 230/230 [==============================] - 2s 8ms/step - loss: 2.1048 - accuracy: 0.6470 - val_loss: 0.6688 - val_accuracy: 0.8022
# Epoch 6/51
# 230/230 [==============================] - 2s 8ms/step - loss: 1.7223 - accuracy: 0.6953 - val_loss: 0.6764 - val_accuracy: 0.7781
# Epoch 7/51
# 230/230 [==============================] - 2s 8ms/step - loss: 4.6392 - accuracy: 0.5095 - val_loss: 5.5880 - val_accuracy: 0.5025
# Epoch 8/51
# 230/230 [==============================] - 2s 8ms/step - loss: 4.0450 - accuracy: 0.5594 - val_loss: 1.0036 - val_accuracy: 0.7910
# Epoch 9/51
# 230/230 [==============================] - 2s 9ms/step - loss: 4.6339 - accuracy: 0.4973 - val_loss: 5.3852 - val_accuracy: 0.3702
# Epoch 10/51
# 230/230 [==============================] - 2s 9ms/step - loss: 5.0505 - accuracy: 0.4856 - val_loss: 5.1691 - val_accuracy: 0.5266
# Epoch 11/51
# 230/230 [==============================] - 2s 10ms/step - loss: 5.0551 - accuracy: 0.4973 - val_loss: 5.2657 - val_accuracy: 0.5114
# Epoch 12/51
# 230/230 [==============================] - 2s 9ms/step - loss: 5.0775 - accuracy: 0.4956 - val_loss: 5.2440 - val_accuracy: 0.5266
# Epoch 13/51
# 230/230 [==============================] - 2s 10ms/step - loss: 4.9187 - accuracy: 0.5098 - val_loss: 5.2582 - val_accuracy: 0.5090
# Epoch 14/51
# 230/230 [==============================] - 2s 9ms/step - loss: 4.5102 - accuracy: 0.4886 - val_loss: 0.8580 - val_accuracy: 0.5348
# Epoch 15/51
# 230/230 [==============================] - 2s 10ms/step - loss: 3.8711 - accuracy: 0.5282 - val_loss: 6.0025 - val_accuracy: 0.5270
# Epoch 16/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.1709 - accuracy: 0.4667 - val_loss: 8.8572 - val_accuracy: 0.3943
# Epoch 17/51
# 230/230 [==============================] - 2s 8ms/step - loss: 9.9366 - accuracy: 0.2318 - val_loss: 11.9176 - val_accuracy: 0.1805
# Epoch 18/51
# 230/230 [==============================] - 2s 8ms/step - loss: 9.0477 - accuracy: 0.2042 - val_loss: 8.2566 - val_accuracy: 0.3156
# Epoch 19/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.9850 - accuracy: 0.2578 - val_loss: 7.9118 - val_accuracy: 0.3590
# Epoch 20/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.4362 - accuracy: 0.3224 - val_loss: 7.9822 - val_accuracy: 0.3478
# Epoch 21/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.1226 - accuracy: 0.3384 - val_loss: 7.8374 - val_accuracy: 0.3780
# Epoch 22/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.0915 - accuracy: 0.3425 - val_loss: 7.9164 - val_accuracy: 0.3980
# Epoch 23/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.1423 - accuracy: 0.3449 - val_loss: 7.9957 - val_accuracy: 0.3641
# Epoch 24/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.0527 - accuracy: 0.3629 - val_loss: 7.7866 - val_accuracy: 0.4374
# Epoch 25/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.0164 - accuracy: 0.3732 - val_loss: 8.1235 - val_accuracy: 0.4007
# Epoch 26/51
# 230/230 [==============================] - 2s 8ms/step - loss: 7.0753 - accuracy: 0.4022 - val_loss: 8.7209 - val_accuracy: 0.3651
# Epoch 27/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.8983 - accuracy: 0.3961 - val_loss: 7.7125 - val_accuracy: 0.4791
# Epoch 28/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.9157 - accuracy: 0.3995 - val_loss: 7.7334 - val_accuracy: 0.4866
# Epoch 29/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.7828 - accuracy: 0.4027 - val_loss: 8.2102 - val_accuracy: 0.4459
# Epoch 30/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.6789 - accuracy: 0.4187 - val_loss: 7.9231 - val_accuracy: 0.4608
# Epoch 31/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.6090 - accuracy: 0.4124 - val_loss: 8.5825 - val_accuracy: 0.4340
# Epoch 32/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.7130 - accuracy: 0.4097 - val_loss: 7.8757 - val_accuracy: 0.4964
# Epoch 33/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.5760 - accuracy: 0.4219 - val_loss: 7.9066 - val_accuracy: 0.4964
# Epoch 34/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.5559 - accuracy: 0.4251 - val_loss: 7.7949 - val_accuracy: 0.4998
# Epoch 35/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5239 - accuracy: 0.4237 - val_loss: 8.0897 - val_accuracy: 0.4751
# Epoch 36/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5407 - accuracy: 0.4332 - val_loss: 7.8666 - val_accuracy: 0.4988
# Epoch 37/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5069 - accuracy: 0.4411 - val_loss: 7.8889 - val_accuracy: 0.4835
# Epoch 38/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.3303 - accuracy: 0.4472 - val_loss: 7.9038 - val_accuracy: 0.4924
# Epoch 39/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4413 - accuracy: 0.4421 - val_loss: 7.9415 - val_accuracy: 0.4964
# Epoch 40/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5060 - accuracy: 0.4562 - val_loss: 7.7751 - val_accuracy: 0.4971
# Epoch 41/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4279 - accuracy: 0.4567 - val_loss: 7.8230 - val_accuracy: 0.4998
# Epoch 42/51
# 230/230 [==============================] - 2s 10ms/step - loss: 6.5821 - accuracy: 0.4415 - val_loss: 8.2168 - val_accuracy: 0.4652
# Epoch 43/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.5359 - accuracy: 0.4450 - val_loss: 7.7864 - val_accuracy: 0.5019
# Epoch 44/51
# 230/230 [==============================] - 2s 10ms/step - loss: 6.5250 - accuracy: 0.4597 - val_loss: 7.7629 - val_accuracy: 0.4988
# Epoch 45/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.6913 - accuracy: 0.4397 - val_loss: 11.7705 - val_accuracy: 0.2528
# Epoch 46/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.7806 - accuracy: 0.4282 - val_loss: 7.9206 - val_accuracy: 0.4954
# Epoch 47/51
# 230/230 [==============================] - 2s 9ms/step - loss: 6.5069 - accuracy: 0.4585 - val_loss: 7.8141 - val_accuracy: 0.5036
# Epoch 48/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4035 - accuracy: 0.4604 - val_loss: 7.8955 - val_accuracy: 0.5056
# Epoch 49/51
# 230/230 [==============================] - 2s 8ms/step - loss: 8.0273 - accuracy: 0.3498 - val_loss: 10.8288 - val_accuracy: 0.3132
# Epoch 50/51
# 230/230 [==============================] - 2s 8ms/step - loss: 8.2420 - accuracy: 0.3157 - val_loss: 8.0000 - val_accuracy: 0.4944
# Epoch 51/51
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4122 - accuracy: 0.4191 - val_loss: 8.0733 - val_accuracy: 0.4835

# %%
model.summary()

import tensorflow as tf
from tensorflow import keras

Callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", patience=3)
mo_fitt = model.fit(
    x_train, y_train, epochs=200, validation_data=(x_test, y_test), callbacks=Callback
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 160)               89920
#
#  dense_1 (Dense)             (None, 352)               56672
#
#  dense_2 (Dense)             (None, 384)               135552
#
#  dense_3 (Dense)             (None, 160)               61600
#
#  dense_4 (Dense)             (None, 512)               82432
#
#  dense_5 (Dense)             (None, 224)               114912
#
#  dense_6 (Dense)             (None, 352)               79200
#
#  dense_7 (Dense)             (None, 416)               146848
#
#  dense_8 (Dense)             (None, 128)               53376
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dense_10 (Dense)            (None, 6)                 774
#
#  dropout (Dropout)           (None, 6)                 0
#
# =================================================================
# Total params: 837,798
# Trainable params: 837,798
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
#   6/230 [..............................] - ETA: 2s - loss: 9.7614 - accuracy: 0.2083
# 2023-05-30 19:38:28.345893: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 16497888 exceeds 10% of free system memory.
# 230/230 [==============================] - 2s 10ms/step - loss: 8.4543 - accuracy: 0.3052 - val_loss: 8.0056 - val_accuracy: 0.4937
# Epoch 2/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4706 - accuracy: 0.4163 - val_loss: 8.1294 - val_accuracy: 0.4815
# Epoch 3/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4027 - accuracy: 0.4183 - val_loss: 7.9322 - val_accuracy: 0.4890
# Epoch 4/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4020 - accuracy: 0.4227 - val_loss: 7.9569 - val_accuracy: 0.4954
# Epoch 5/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4665 - accuracy: 0.4229 - val_loss: 8.0427 - val_accuracy: 0.4781
# Epoch 6/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4158 - accuracy: 0.4223 - val_loss: 8.0984 - val_accuracy: 0.4696
# Epoch 7/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4162 - accuracy: 0.4253 - val_loss: 7.8793 - val_accuracy: 0.4998
# Epoch 8/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.2934 - accuracy: 0.4276 - val_loss: 7.9270 - val_accuracy: 0.4883
# Epoch 9/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3747 - accuracy: 0.4335 - val_loss: 7.8725 - val_accuracy: 0.4995
# Epoch 10/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4233 - accuracy: 0.4389 - val_loss: 7.8959 - val_accuracy: 0.5019
# Epoch 11/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3984 - accuracy: 0.4312 - val_loss: 7.9055 - val_accuracy: 0.4968
# Epoch 12/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4174 - accuracy: 0.4471 - val_loss: 7.8612 - val_accuracy: 0.4934
# Epoch 13/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3856 - accuracy: 0.4531 - val_loss: 7.8556 - val_accuracy: 0.4981
# Epoch 14/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4411 - accuracy: 0.4536 - val_loss: 7.8272 - val_accuracy: 0.5029
# Epoch 15/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4017 - accuracy: 0.4593 - val_loss: 7.8808 - val_accuracy: 0.5046
# Epoch 16/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.4151 - accuracy: 0.4558 - val_loss: 8.0148 - val_accuracy: 0.4825
# Epoch 17/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5278 - accuracy: 0.4558 - val_loss: 7.8733 - val_accuracy: 0.5015
# Epoch 18/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3114 - accuracy: 0.4646 - val_loss: 7.8670 - val_accuracy: 0.5015
# Epoch 19/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3378 - accuracy: 0.4689 - val_loss: 7.8938 - val_accuracy: 0.5022
# Epoch 20/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.3571 - accuracy: 0.4667 - val_loss: 7.8997 - val_accuracy: 0.4863
# Epoch 21/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.3504 - accuracy: 0.4630 - val_loss: 7.9891 - val_accuracy: 0.4900
# Epoch 22/200
# 230/230 [==============================] - 2s 9ms/step - loss: 6.2914 - accuracy: 0.4695 - val_loss: 7.9175 - val_accuracy: 0.4975
# Epoch 23/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4476 - accuracy: 0.4640 - val_loss: 8.2725 - val_accuracy: 0.4659
# Epoch 24/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.5209 - accuracy: 0.4512 - val_loss: 8.7279 - val_accuracy: 0.4272
# Epoch 25/200
# 230/230 [==============================] - 2s 8ms/step - loss: 6.4877 - accuracy: 0.4577 - val_loss: 7.8133 - val_accuracy: 0.5053

# %%
accuracy = mo_fitt.history["accuracy"]
loss = mo_fitt.history["loss"]
validation_loss = mo_fitt.history["val_loss"]
validation_accuracy = mo_fitt.history["val_accuracy"]

# dynamically set x based on y
x = range(len(validation_loss))

plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(x, accuracy, label="Training Accuracy", color="blue", linewidth=2)
plt.plot(
    x, validation_accuracy, label="Validation Accuracy", color="green", linewidth=2
)
plt.legend(loc="lower right", fontsize=14)
plt.title("Accuracy: Training vs Validation", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("Accuracy", fontsize=14)
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(x, loss, label="Training Loss", color="blue", linewidth=2)
plt.plot(x, validation_loss, label="Validation Loss", color="green", linewidth=2)
plt.legend(loc="upper right", fontsize=14)
plt.title("Loss: Training vs Validation", fontsize=16)
plt.xlabel("Epoch", fontsize=14)
plt.ylabel("Loss", fontsize=14)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Save model(s) for development purposes
import tensorflow as tf

# create a TFLiteConverter object
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# convert the model to TFLite format
tflite_model = converter.convert()

# save the TFLite model to a file
with open("./assets/model2.tflite", "wb") as f:
    f.write(tflite_model)
